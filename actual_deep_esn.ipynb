# %% [markdown]
# # Implementation of a KANBoost
# ## Initialisations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pykan
# Out:
# Collecting pykan
#   Downloading pykan-0.2.8-py3-none-any.whl.metadata (11 kB)
# Downloading pykan-0.2.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: pykan
# Successfully installed pykan-0.2.8

# %% [markdown]
# # Sample inputs
#
# > Add blockquote

# %%
import torch
from sklearn.model_selection import train_test_split

if torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")

print("****** DEVICE: ",device , " ******\n")
# Out:
# ****** DEVICE:  cuda  ******

# %% [markdown]
# # KANBoost Preprocessor Class Implementation

# %%
class Preprocessor:
    def __init__(self, page_size, block_size):
        self.page_size = page_size
        self.block_size = block_size

    def ensure_48bit_address(self, load_address):
        # Ensure the load_address is a 48-bit binary string
        return bin(int(load_address, 16))[2:].zfill(48)

    def calculate_delta(self, block1, block2):
        # Calculate the delta between two blocks (binary subtraction)
        return int(block1, 2) - int(block2, 2)

    def split_load_address(self, load_address):
        binary_address = self.ensure_48bit_address(load_address)

        page = binary_address[:self.page_size]  # x Bit (Varies)
        block = binary_address[self.page_size:self.page_size + self.block_size]  # 6 Bit Fixed
        block_offset = binary_address[self.page_size + self.block_size:]  # Remaining bits

        return (page, block, block_offset)


    def unsplit_load_address(self, load_address, block_delta):
        # Convert the load address (hex) to binary
        binary_address = self.ensure_48bit_address(load_address)

        # Split the binary address into page, block, and offset
        current_page = binary_address[:self.page_size]
        current_block = binary_address[self.page_size:self.page_size + self.block_size]
        current_block_offset = binary_address[self.page_size + self.block_size:]
        adjusted_block_int=int(current_block, 2) + block_delta
        if(adjusted_block_int<0):
          adjusted_block_int=0
        # Adjust the block by adding the block delta
        adjusted_block = bin(adjusted_block_int)[2:].zfill(self.block_size)  # Add delta to block and ensure correct bit length
        # Reconstruct the binary address
        reconstructed_binary_address = current_page + adjusted_block + current_block_offset

        # Convert the reconstructed binary address to hexadecimal
        reconstructed_load_address = hex(int(reconstructed_binary_address, 2))[2:].lower()  # Remove '0x' prefix and convert to uppercase

        return reconstructed_load_address

    def preprocess_data(self, data):
        input_features = []
        output_labels = []
        page_blocks = {}
        preprocessed_details = []  # Store detailed information

        for i in range(len(data) - 1):
            instr_id, cycle_count, load_address, instr_ptr, llc_hit_miss = data[i]
            current_page, current_block, current_block_offset = self.split_load_address(load_address)

            _, _, next_load_address, _, _ = data[i+1]
            next_page, next_block, next_block_offset = self.split_load_address(next_load_address)
            # Initialize page_blocks if current_page is not present
            if current_page not in page_blocks:
                page_blocks[current_page] = ['000001']

            # Calculate delta values for the past blocks
            delta1 = delta2 = delta3 = delta4 = delta5 = 1 + 64

            if len(page_blocks[current_page]) > 1:
                delta1 = 64 + self.calculate_delta(page_blocks[current_page][-1], page_blocks[current_page][-2])
            if len(page_blocks[current_page]) > 2:
                delta2 = 64 + self.calculate_delta(page_blocks[current_page][-2], page_blocks[current_page][-3])
            if len(page_blocks[current_page]) > 3:
                delta3 = 64 + self.calculate_delta(page_blocks[current_page][-3], page_blocks[current_page][-4])
            if len(page_blocks[current_page]) > 4:
                delta4 = 64 + self.calculate_delta(page_blocks[current_page][-4], page_blocks[current_page][-5])
            if len(page_blocks[current_page]) > 5:
                delta5 = 64 + self.calculate_delta(page_blocks[current_page][-4], page_blocks[current_page][-5])

            # Calculate delta for the next block (relative to current block)
            next_delta = self.calculate_delta(next_block, current_block)

            # Append input features
            input_features.append((instr_id,load_address, delta1, delta2, delta3, delta4, delta5))

            # Convert next_delta to a 128-dimensional one-hot array and append as the output label
            output_labels.append(next_delta+64)

            # Append the current block to the page's block list
            page_blocks[current_page].append(current_block)

            # Store the details for inspection without delta1, delta2, delta3, and next_delta
            details = {
                "instr_id": instr_id,
                "page": current_page,
                "block": current_block,
                "block_offset": current_block_offset
            }
            preprocessed_details.append(details)

        return input_features, output_labels, preprocessed_details

# %% [markdown]
# # Read Data from file Implementation

# %%
# Reading the data from the text file (same as before)
def read_data_from_file(filename):
    data = []
    with open(filename, 'r', newline='', encoding='utf-8') as file:  # Specify newline='' to handle any line endings
        for line in file:
            line = line.rstrip('\n')  # Strip only the trailing newline to preserve leading newlines if necessary
            if line:
                # Split by comma and remove any extra spaces
                fields = [x.strip() for x in line.split(',')]
                instr_id = int(fields[0])
                cycle_count = int(fields[1])
                load_address = fields[2]
                instr_ptr = fields[3]
                llc_hit_miss = int(fields[4])

                # Append as a tuple
                data.append((instr_id, cycle_count, load_address, instr_ptr, llc_hit_miss))
    return data

# %% [markdown]
# # Prepare Dataset Function Implementation

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

def prepare_dataset(input_features, output_labels, batch_size=1, device='cpu'):
    """
    Prepares the dataset for training and testing without train-test split, and preserves instruction IDs.

    Args:
        input_features (list or np.array): The input features for the dataset.
        output_labels (list or np.array): The output labels for the dataset.
        batch_size (int): The batch size for data loaders. Default is 1.
        device (str): The device to store the tensors ('cpu' or 'cuda'). Default is 'cpu'.

    Returns:
        dict: A dictionary containing the processed dataset with 'input', 'labels', and 'instr_ids'.
    """
    # Assuming input_features is a list of tuples like (instr_id, feature1, feature2, ..., featureN)
    instr_ids = [x[0] for x in input_features]  # Extracting the instruction IDs
    features = [x[2:] for x in input_features]   # Extracting the actual feature data (excluding instr_id)

    # Convert to PyTorch tensors and move to the specified device
    data_tensor = torch.tensor(features, dtype=torch.float32, device=device)
    target_tensor = torch.tensor(output_labels, dtype=torch.long, device=device)  # Assuming labels are integer values

    # Create data loaders (optional, if you want to batch and shuffle the data)
    data_loader = DataLoader(TensorDataset(data_tensor, target_tensor),
                             batch_size=batch_size, shuffle=True)

    # Initialize tensors for inputs and labels
    all_inputs = torch.empty(0, data_tensor.size(1), device=device)  # Assuming data_tensor has N features
    all_labels = torch.empty(0, dtype=torch.long, device=device)

    # Concatenate all data into a single tensor on the specified device
    for data, labels in data_loader:
        all_inputs = torch.cat((all_inputs, data.to(device)), dim=0)
        all_labels = torch.cat((all_labels, labels.to(device)), dim=0)

    # Return the dataset as a dictionary, including instruction IDs
    dataset = {
        'input': all_inputs,
        'label': all_labels,
        'instr_ids': instr_ids  # Include the instruction IDs in the output (no need to move to device)
    }

    return dataset


  # ------------------------****** Load Dataset for Training only ******  ------------------------
def load_dataset(data,target):
    # Convert to PyTorch tensors
   #This needs to be torch.float32

    # Split dataset into train and test sets
    data_tensor = torch.tensor(data, dtype=torch.float32)
    target_tensor = torch.tensor(target, dtype=torch.long)

    # Split dataset deterministically (e.g., first 80% for training, last 20% for testing)
    split_index = int(len(data_tensor) * 0.8)  # 80-20 split

    train_data = data_tensor[:split_index]
    test_data = data_tensor[split_index:]
    train_target = target_tensor[:split_index]
    test_target = target_tensor[split_index:]

    # Create data loaders (optional, if you want to batch and shuffle the data)
    train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(train_data, train_target), batch_size=1, shuffle=False)
    test_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(test_data, test_target), batch_size=1, shuffle=False)

    train_inputs = torch.empty(0, 5, device=device)
    train_labels = torch.empty(0, dtype=torch.long,device=device)
    test_inputs = torch.empty(0, 5, device=device)
    test_labels = torch.empty(0,dtype=torch.long,  device=device)

    # Concatenate all data into a single tensor on the specified device
    for data, labels in train_loader:
        train_inputs = torch.cat((train_inputs, data.to(device)), dim=0)
        train_labels = torch.cat((train_labels, labels.to(device)), dim=0)

    for data, labels in test_loader:
        test_inputs = torch.cat((test_inputs, data.to(device)), dim=0)
        test_labels = torch.cat((test_labels, labels.to(device)), dim=0)

    dataset = {}
    dataset['train_input'] = train_inputs
    dataset['test_input'] = test_inputs
    dataset['train_label'] = train_labels
    dataset['test_label'] = test_labels

    return dataset

# %% [markdown]
# # KANBoost Entry Point:

# %%
filename = '/content/drive/MyDrive/482.sphinx3-s2.trace.gz-hashed_perceptron-no-no-no-trace-lru-1core.txt'
data = read_data_from_file(filename)

# Initialize the KANBoost Preprocessor
page_size = 36
block_size = 6

preprocessor = Preprocessor(page_size, block_size)

# Use the preprocess_data function to process the entire data and capture details
input_features, output_labels, preprocessed_details = preprocessor.preprocess_data(data)
# dataset=prepare_dataset(input_features=input_features,output_labels=output_labels,device=device)

# %%
input_features[0]
# Out:
# (3, '5cb41dc41440', 65, 65, 65, 65, 65)

# %%
last_5_elements = [t[-5:] for t in input_features]

# %%
dataset=load_dataset(last_5_elements,output_labels)

# %%
print("Train data shape: {}".format(dataset['train_input'].shape))
print("Train target shape: {}".format(dataset['train_label'].shape))
print("Test data shape: {}".format(dataset['test_input'].shape))
print("Test target shape: {}".format(dataset['test_label'].shape))
# Out:
# Train data shape: torch.Size([234214, 5])
# Train target shape: torch.Size([234214])
# Test data shape: torch.Size([58554, 5])
# Test target shape: torch.Size([58554])

# %% [markdown]
# ## Creating and Training the Echo state network
#
# *   List item
# *   List item

# %%
class DeepEchoStateNetwork(torch.nn.Module):
    def __init__(self, input_dim, reservoir_sizes, output_dim, spectral_radius=0.95):
        super(DeepEchoStateNetwork, self).__init__()
        self.reservoir_sizes = reservoir_sizes

        # Initialize weight matrices for each reservoir layer
        self.Win_layers = []
        self.W_layers = []

        for i, reservoir_size in enumerate(reservoir_sizes):
            prev_dim = input_dim if i == 0 else reservoir_sizes[i - 1]

            # Input-to-reservoir weights
            Win = torch.randn(reservoir_size, prev_dim) * 0.1
            self.Win_layers.append(Win)

            # Reservoir-to-reservoir weights
            W = torch.randn(reservoir_size, reservoir_size) * 0.1
            max_eigenvalue = max(abs(torch.linalg.eigvals(W).real))
            W_scaled = W * (spectral_radius / max_eigenvalue)
            self.W_layers.append(W_scaled)

        # Register the weights as buffers (non-trainable parameters)
        for i, (Win, W) in enumerate(zip(self.Win_layers, self.W_layers)):
            self.register_buffer(f'Win_{i}', Win)
            self.register_buffer(f'W_{i}', W)

        # Output layer (readout)
        self.Wout = torch.nn.Linear(reservoir_sizes[-1], output_dim)

    def forward(self, x):
        device = x.device
        batch_size = x.shape[0]

        # Initialize reservoir state
        reservoir_state = None

        # Iterate through reservoir layers
        for i in range(len(self.reservoir_sizes)):
            # Get weights for this layer
            Win = getattr(self, f'Win_{i}').to(device)
            W = getattr(self, f'W_{i}').to(device)

            if reservoir_state is None:
                reservoir_state = torch.zeros(batch_size, Win.shape[0], device=device)

            # Update reservoir state
            reservoir_state = torch.tanh(
                torch.matmul(x, Win.T) + torch.matmul(reservoir_state, W.T)
            )

            # Pass state to the next layer
            x = reservoir_state

        # Output layer
        return self.Wout(reservoir_state)

# %%
def clear_gpu_memory():
    """Clear GPU memory cache."""
    torch.cuda.empty_cache()
    if torch.cuda.is_available():
        torch.cuda.synchronize()  # Wait for all streams on a CUDA device to finish
    print("GPU memory cleared.")
clear_gpu_memory()
# Out:
# GPU memory cleared.

# %%
def Train_KANBoost(dataset, model, optimizer, criterion):
    def train_acc():
        with torch.no_grad():
            predictions = torch.argmax(model(dataset['train_input']), dim=1)
            return torch.mean((predictions == dataset['train_label']).float())

    def test_acc():
        with torch.no_grad():
            predictions = torch.argmax(model(dataset['test_input']), dim=1)
            return torch.mean((predictions == dataset['test_label']).float())

    # Training step
    optimizer.zero_grad()
    outputs = model(dataset['train_input'])
    loss = criterion(outputs, dataset['train_label'])
    loss.backward()
    optimizer.step()

    # Evaluate metrics
    train_accuracy = train_acc()
    test_accuracy = test_acc()

    print(f"Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}, Loss: {loss.item():.4f}")

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

def train_model(dataset, num_epochs=10, input_dim=None, output_dim=None, reservoir_sizes=[100]):
    # Determine the device (CPU or GPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Move input and labels to the appropriate device (not the TensorDataset itself)
    train_input = dataset['train_input'].to(device)
    train_label = dataset['train_label'].to(device)
    test_input = dataset['test_input'].to(device)
    test_label = dataset['test_label'].to(device)

    # Step 1: Create TensorDataset for train and test datasets
    train_dataset = TensorDataset(train_input, train_label)
    test_dataset = TensorDataset(test_input, test_label)

    # Step 2: Create DataLoader for both train and test datasets
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Initialize Deep ESN model
    esn_model = DeepEchoStateNetwork(input_dim, reservoir_sizes, output_dim).to(device)  # Move model to device
    optimizer = torch.optim.Adam(esn_model.parameters(), lr=0.01)
    criterion = torch.nn.CrossEntropyLoss()

    # Step 3: Iterate through the DataLoader for training
    for epoch in range(num_epochs):
        print("Epoch going",epoch)
        for train_batch, test_batch in zip(train_loader, test_loader):
            train_inputs, train_targets = train_batch
            test_inputs, test_targets = test_batch

            # Move batch data to the same device
            train_inputs = train_inputs.to(device)
            train_targets = train_targets.to(device)
            test_inputs = test_inputs.to(device)
            test_targets = test_targets.to(device)

            partial_dataset = {
                "train_input": train_inputs,
                "train_label": train_targets,
                "test_input": test_inputs,
                "test_label": test_targets
            }
            Train_KANBoost(partial_dataset, esn_model, optimizer, criterion)

    # Save the trained model
    torch.save(esn_model.state_dict(), "trained_esn_model.pth")

# %%
input_dim = dataset['train_input'].shape[1]
indivsize=1000
num_layers=6
reservoir_sizes=[]
for i in range(0,num_layers):
  reservoir_sizes.append(num_layers)
train_model(dataset, num_epochs=50, input_dim=input_dim, output_dim=128, reservoir_sizes=reservoir_sizes)
print("Model saved to trained_esn_model.pth")
# Out:
# Streaming output truncated to the last 5000 lines.
# Train Accuracy: 0.2656, Test Accuracy: 0.4688, Loss: 3.5452
# Train Accuracy: 0.2500, Test Accuracy: 0.3906, Loss: 2.9456
# Train Accuracy: 0.2812, Test Accuracy: 0.4375, Loss: 2.7161
# Train Accuracy: 0.3438, Test Accuracy: 0.4688, Loss: 2.8517
# Train Accuracy: 0.3438, Test Accuracy: 0.3750, Loss: 3.1246
# Train Accuracy: 0.3906, Test Accuracy: 0.4531, Loss: 3.0976
# Train Accuracy: 0.1875, Test Accuracy: 0.4062, Loss: 3.4871
# Train Accuracy: 0.2500, Test Accuracy: 0.4062, Loss: 3.3976
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.1339
# Train Accuracy: 0.2344, Test Accuracy: 0.4375, Loss: 3.5875
# Train Accuracy: 0.2031, Test Accuracy: 0.4375, Loss: 3.4315
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 3.2347
# Train Accuracy: 0.3281, Test Accuracy: 0.4531, Loss: 3.0403
# Train Accuracy: 0.1875, Test Accuracy: 0.3750, Loss: 3.5196
# Train Accuracy: 0.1875, Test Accuracy: 0.4688, Loss: 3.1448
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.0572
# Train Accuracy: 0.3906, Test Accuracy: 0.3906, Loss: 2.9753
# Train Accuracy: 0.2656, Test Accuracy: 0.4375, Loss: 3.1102
# Train Accuracy: 0.1406, Test Accuracy: 0.4375, Loss: 3.6079
# Train Accuracy: 0.2188, Test Accuracy: 0.3906, Loss: 3.0667
# Train Accuracy: 0.2344, Test Accuracy: 0.4219, Loss: 3.2062
# Train Accuracy: 0.2500, Test Accuracy: 0.4375, Loss: 3.7586
# Train Accuracy: 0.2656, Test Accuracy: 0.4375, Loss: 3.1904
# Train Accuracy: 0.2031, Test Accuracy: 0.4062, Loss: 3.2590
# Train Accuracy: 0.2656, Test Accuracy: 0.4531, Loss: 2.9280
# Train Accuracy: 0.2500, Test Accuracy: 0.3906, Loss: 3.5947
# Train Accuracy: 0.3281, Test Accuracy: 0.4531, Loss: 3.3708
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.0946
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.4457
# Train Accuracy: 0.2500, Test Accuracy: 0.4375, Loss: 3.3320
# Train Accuracy: 0.3906, Test Accuracy: 0.4062, Loss: 2.7180
# Train Accuracy: 0.2188, Test Accuracy: 0.4531, Loss: 3.5459
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.1695
# Train Accuracy: 0.2969, Test Accuracy: 0.4375, Loss: 3.5674
# Train Accuracy: 0.3750, Test Accuracy: 0.4375, Loss: 3.0869
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.2555
# Train Accuracy: 0.3594, Test Accuracy: 0.4375, Loss: 2.8896
# Train Accuracy: 0.2344, Test Accuracy: 0.3906, Loss: 3.3676
# Train Accuracy: 0.2969, Test Accuracy: 0.4375, Loss: 3.1445
# Train Accuracy: 0.2344, Test Accuracy: 0.4531, Loss: 3.4512
# Train Accuracy: 0.4062, Test Accuracy: 0.3750, Loss: 2.6960
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.4115
# Train Accuracy: 0.2812, Test Accuracy: 0.4375, Loss: 2.9286
# Train Accuracy: 0.3281, Test Accuracy: 0.4219, Loss: 3.0872
# Train Accuracy: 0.2656, Test Accuracy: 0.4375, Loss: 3.1875
# Train Accuracy: 0.2188, Test Accuracy: 0.4688, Loss: 3.5720
# Train Accuracy: 0.2656, Test Accuracy: 0.4062, Loss: 3.7343
# Train Accuracy: 0.2656, Test Accuracy: 0.4531, Loss: 3.3254
# Train Accuracy: 0.2500, Test Accuracy: 0.4531, Loss: 3.3044
# Train Accuracy: 0.2344, Test Accuracy: 0.3906, Loss: 3.2941
# Train Accuracy: 0.3281, Test Accuracy: 0.4375, Loss: 2.7114
# Train Accuracy: 0.3125, Test Accuracy: 0.4531, Loss: 2.9258
# Train Accuracy: 0.2812, Test Accuracy: 0.4375, Loss: 3.0187
# Train Accuracy: 0.2031, Test Accuracy: 0.4219, Loss: 3.7800
# Train Accuracy: 0.2500, Test Accuracy: 0.4219, Loss: 3.2826
# Train Accuracy: 0.3594, Test Accuracy: 0.4375, Loss: 3.0810
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.3235
# Train Accuracy: 0.2969, Test Accuracy: 0.4531, Loss: 3.0741
# Train Accuracy: 0.2031, Test Accuracy: 0.3906, Loss: 3.4009
# Train Accuracy: 0.3594, Test Accuracy: 0.4375, Loss: 3.2528
# Train Accuracy: 0.3125, Test Accuracy: 0.4062, Loss: 2.8003
# Train Accuracy: 0.2656, Test Accuracy: 0.3594, Loss: 3.0173
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 3.3349
# Train Accuracy: 0.2656, Test Accuracy: 0.3750, Loss: 3.0448
# Train Accuracy: 0.2500, Test Accuracy: 0.3906, Loss: 3.3093
# Train Accuracy: 0.2656, Test Accuracy: 0.4062, Loss: 3.0737
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 2.8951
# Train Accuracy: 0.3125, Test Accuracy: 0.3750, Loss: 3.1107
# Train Accuracy: 0.3594, Test Accuracy: 0.3906, Loss: 2.6969
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 2.9569
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.2372
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.0484
# Train Accuracy: 0.2656, Test Accuracy: 0.4062, Loss: 3.7157
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.1959
# Train Accuracy: 0.2344, Test Accuracy: 0.3750, Loss: 3.6672
# Train Accuracy: 0.3750, Test Accuracy: 0.3594, Loss: 2.7436
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.1595
# Train Accuracy: 0.3594, Test Accuracy: 0.4062, Loss: 2.7314
# Train Accuracy: 0.3281, Test Accuracy: 0.3594, Loss: 3.4677
# Train Accuracy: 0.3750, Test Accuracy: 0.4062, Loss: 2.9202
# Train Accuracy: 0.3125, Test Accuracy: 0.4219, Loss: 3.2212
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 2.9624
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 2.8933
# Train Accuracy: 0.2812, Test Accuracy: 0.3594, Loss: 3.2940
# Train Accuracy: 0.2344, Test Accuracy: 0.4375, Loss: 3.1675
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 3.1265
# Train Accuracy: 0.2344, Test Accuracy: 0.3750, Loss: 3.6223
# Train Accuracy: 0.2969, Test Accuracy: 0.3750, Loss: 3.3303
# Train Accuracy: 0.2500, Test Accuracy: 0.3906, Loss: 3.1267
# Train Accuracy: 0.3125, Test Accuracy: 0.3750, Loss: 3.4066
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.3349
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.4955
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.1816
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 2.9406
# Train Accuracy: 0.2656, Test Accuracy: 0.3750, Loss: 3.0553
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.2552
# Train Accuracy: 0.3125, Test Accuracy: 0.4219, Loss: 3.3363
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 3.3075
# Train Accuracy: 0.3750, Test Accuracy: 0.3750, Loss: 2.9457
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.1153
# Train Accuracy: 0.3594, Test Accuracy: 0.3906, Loss: 3.0498
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.3349
# Train Accuracy: 0.3594, Test Accuracy: 0.4219, Loss: 2.8124
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.6077
# Train Accuracy: 0.2031, Test Accuracy: 0.3906, Loss: 3.3408
# Train Accuracy: 0.3281, Test Accuracy: 0.3750, Loss: 2.8691
# Train Accuracy: 0.2031, Test Accuracy: 0.3594, Loss: 3.5269
# Train Accuracy: 0.2188, Test Accuracy: 0.4062, Loss: 3.0237
# Train Accuracy: 0.2656, Test Accuracy: 0.3750, Loss: 2.9021
# Train Accuracy: 0.2188, Test Accuracy: 0.3750, Loss: 3.2129
# Train Accuracy: 0.2188, Test Accuracy: 0.4062, Loss: 3.1991
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.3658
# Train Accuracy: 0.2656, Test Accuracy: 0.4219, Loss: 3.7222
# Train Accuracy: 0.2812, Test Accuracy: 0.3594, Loss: 3.1741
# Train Accuracy: 0.3750, Test Accuracy: 0.4062, Loss: 2.9957
# Train Accuracy: 0.4219, Test Accuracy: 0.4375, Loss: 2.7122
# Train Accuracy: 0.3125, Test Accuracy: 0.3750, Loss: 3.1761
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.0332
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.5323
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 2.9580
# Train Accuracy: 0.1875, Test Accuracy: 0.3906, Loss: 3.6313
# Train Accuracy: 0.4062, Test Accuracy: 0.3750, Loss: 3.2244
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.0645
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.0656
# Train Accuracy: 0.2500, Test Accuracy: 0.4062, Loss: 3.5558
# Train Accuracy: 0.2500, Test Accuracy: 0.3594, Loss: 2.9947
# Train Accuracy: 0.3594, Test Accuracy: 0.3906, Loss: 2.9124
# Train Accuracy: 0.3750, Test Accuracy: 0.4219, Loss: 2.5623
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.2217
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.0512
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.1196
# Train Accuracy: 0.2188, Test Accuracy: 0.3906, Loss: 3.7452
# Train Accuracy: 0.1406, Test Accuracy: 0.4062, Loss: 3.6423
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.1511
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 2.8790
# Train Accuracy: 0.3438, Test Accuracy: 0.3750, Loss: 3.1297
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 2.6440
# Train Accuracy: 0.2656, Test Accuracy: 0.3438, Loss: 3.1493
# Train Accuracy: 0.1875, Test Accuracy: 0.4219, Loss: 3.5492
# Train Accuracy: 0.2812, Test Accuracy: 0.3750, Loss: 3.1848
# Train Accuracy: 0.2344, Test Accuracy: 0.3750, Loss: 3.3212
# Train Accuracy: 0.3281, Test Accuracy: 0.4219, Loss: 3.2864
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.0356
# Train Accuracy: 0.2500, Test Accuracy: 0.3906, Loss: 3.5784
# Train Accuracy: 0.2969, Test Accuracy: 0.3594, Loss: 3.1548
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.2700
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 3.3081
# Train Accuracy: 0.4062, Test Accuracy: 0.3594, Loss: 2.5919
# Train Accuracy: 0.3438, Test Accuracy: 0.3906, Loss: 2.9810
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.0463
# Train Accuracy: 0.3438, Test Accuracy: 0.3906, Loss: 2.6538
# Train Accuracy: 0.2344, Test Accuracy: 0.3750, Loss: 3.3649
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 2.9685
# Train Accuracy: 0.2500, Test Accuracy: 0.4062, Loss: 3.3007
# Train Accuracy: 0.3438, Test Accuracy: 0.3750, Loss: 2.7577
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 2.9888
# Train Accuracy: 0.3281, Test Accuracy: 0.3594, Loss: 3.0373
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.2371
# Train Accuracy: 0.3594, Test Accuracy: 0.4219, Loss: 2.7013
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 2.7521
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 3.3904
# Train Accuracy: 0.3125, Test Accuracy: 0.3750, Loss: 2.8482
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 2.9995
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.2454
# Train Accuracy: 0.2188, Test Accuracy: 0.3750, Loss: 3.2930
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.3699
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 3.0940
# Train Accuracy: 0.3438, Test Accuracy: 0.3906, Loss: 2.9033
# Train Accuracy: 0.3594, Test Accuracy: 0.3438, Loss: 2.9225
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 3.3108
# Train Accuracy: 0.2344, Test Accuracy: 0.3906, Loss: 3.5786
# Train Accuracy: 0.2031, Test Accuracy: 0.3750, Loss: 3.3150
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 3.1755
# Train Accuracy: 0.2031, Test Accuracy: 0.4062, Loss: 3.5203
# Train Accuracy: 0.1875, Test Accuracy: 0.3906, Loss: 3.2455
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 3.1919
# Train Accuracy: 0.2188, Test Accuracy: 0.4062, Loss: 3.6603
# Train Accuracy: 0.2344, Test Accuracy: 0.4062, Loss: 3.7666
# Train Accuracy: 0.1875, Test Accuracy: 0.4062, Loss: 3.4667
# Train Accuracy: 0.2188, Test Accuracy: 0.3906, Loss: 3.3685
# Train Accuracy: 0.2344, Test Accuracy: 0.3750, Loss: 3.2240
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.3374
# Train Accuracy: 0.2969, Test Accuracy: 0.3750, Loss: 2.9239
# Train Accuracy: 0.2812, Test Accuracy: 0.3750, Loss: 3.2588
# Train Accuracy: 0.3594, Test Accuracy: 0.5781, Loss: 2.7510
# Train Accuracy: 0.2031, Test Accuracy: 0.3594, Loss: 3.4569
# Train Accuracy: 0.2969, Test Accuracy: 0.1406, Loss: 3.3007
# Train Accuracy: 0.3906, Test Accuracy: 0.1562, Loss: 2.6676
# Train Accuracy: 0.1250, Test Accuracy: 0.1875, Loss: 3.6271
# Train Accuracy: 0.2812, Test Accuracy: 0.1719, Loss: 3.1943
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.3975
# Train Accuracy: 0.2344, Test Accuracy: 0.1562, Loss: 3.2675
# Train Accuracy: 0.3125, Test Accuracy: 0.1406, Loss: 3.2427
# Train Accuracy: 0.2656, Test Accuracy: 0.1562, Loss: 3.3583
# Train Accuracy: 0.3125, Test Accuracy: 0.2031, Loss: 2.9939
# Train Accuracy: 0.3281, Test Accuracy: 0.1875, Loss: 3.1310
# Train Accuracy: 0.2812, Test Accuracy: 0.1875, Loss: 3.4851
# Train Accuracy: 0.3125, Test Accuracy: 0.1875, Loss: 3.3634
# Train Accuracy: 0.3281, Test Accuracy: 0.1094, Loss: 2.9560
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 3.1384
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.0901
# Train Accuracy: 0.1875, Test Accuracy: 0.2500, Loss: 3.6045
# Train Accuracy: 0.1875, Test Accuracy: 0.1719, Loss: 3.4634
# Train Accuracy: 0.1562, Test Accuracy: 0.1875, Loss: 3.2236
# Train Accuracy: 0.2656, Test Accuracy: 0.1875, Loss: 3.0636
# Train Accuracy: 0.1875, Test Accuracy: 0.2031, Loss: 3.9632
# Train Accuracy: 0.2969, Test Accuracy: 0.2188, Loss: 3.0471
# Train Accuracy: 0.1719, Test Accuracy: 0.3125, Loss: 3.4581
# Train Accuracy: 0.1719, Test Accuracy: 0.2344, Loss: 3.8271
# Train Accuracy: 0.2344, Test Accuracy: 0.1875, Loss: 3.4341
# Train Accuracy: 0.2344, Test Accuracy: 0.1562, Loss: 3.2872
# Train Accuracy: 0.3281, Test Accuracy: 0.1875, Loss: 2.9319
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.0641
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.1050
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.2772
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 3.3060
# Train Accuracy: 0.2812, Test Accuracy: 0.2344, Loss: 3.3584
# Train Accuracy: 0.2031, Test Accuracy: 0.2500, Loss: 3.3636
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.6041
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.2143
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.2783
# Train Accuracy: 0.1875, Test Accuracy: 0.2812, Loss: 3.3500
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 3.0633
# Train Accuracy: 0.3750, Test Accuracy: 0.2188, Loss: 3.1293
# Train Accuracy: 0.1875, Test Accuracy: 0.2188, Loss: 3.2761
# Train Accuracy: 0.3125, Test Accuracy: 0.2188, Loss: 2.6525
# Train Accuracy: 0.3594, Test Accuracy: 0.2031, Loss: 2.9079
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.1093
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 2.8692
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.3675
# Train Accuracy: 0.2344, Test Accuracy: 0.3125, Loss: 3.6233
# Train Accuracy: 0.3281, Test Accuracy: 0.2188, Loss: 3.3480
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.2766
# Train Accuracy: 0.2969, Test Accuracy: 0.2188, Loss: 3.5108
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.2863
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.0728
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.2284
# Train Accuracy: 0.3906, Test Accuracy: 0.3594, Loss: 2.9111
# Train Accuracy: 0.1875, Test Accuracy: 0.1875, Loss: 3.1797
# Train Accuracy: 0.2500, Test Accuracy: 0.2500, Loss: 3.3923
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.2599
# Train Accuracy: 0.2344, Test Accuracy: 0.2344, Loss: 3.0866
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.1086
# Train Accuracy: 0.2188, Test Accuracy: 0.2656, Loss: 3.5026
# Train Accuracy: 0.2344, Test Accuracy: 0.2500, Loss: 3.3915
# Train Accuracy: 0.2344, Test Accuracy: 0.2188, Loss: 2.9741
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.1494
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.1998
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.0834
# Train Accuracy: 0.2188, Test Accuracy: 0.2500, Loss: 3.2917
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 3.1599
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.3015
# Train Accuracy: 0.2188, Test Accuracy: 0.2656, Loss: 3.5858
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 2.9603
# Train Accuracy: 0.3594, Test Accuracy: 0.2812, Loss: 2.8738
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.1515
# Train Accuracy: 0.3438, Test Accuracy: 0.2344, Loss: 3.1277
# Train Accuracy: 0.3594, Test Accuracy: 0.3125, Loss: 3.0308
# Train Accuracy: 0.3125, Test Accuracy: 0.2188, Loss: 3.0664
# Train Accuracy: 0.2812, Test Accuracy: 0.2344, Loss: 3.4571
# Train Accuracy: 0.2344, Test Accuracy: 0.2344, Loss: 3.1687
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 2.9279
# Train Accuracy: 0.3906, Test Accuracy: 0.2344, Loss: 2.6051
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.4013
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.4244
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.3929
# Train Accuracy: 0.2344, Test Accuracy: 0.2500, Loss: 3.4827
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.2616
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 3.1197
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.0886
# Train Accuracy: 0.3281, Test Accuracy: 0.2188, Loss: 2.8422
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 2.8922
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.1581
# Train Accuracy: 0.3906, Test Accuracy: 0.2656, Loss: 2.7416
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.2407
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.2451
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 2.9064
# Train Accuracy: 0.4062, Test Accuracy: 0.2656, Loss: 2.8727
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.2110
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 3.4505
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 3.3941
# Train Accuracy: 0.3906, Test Accuracy: 0.2656, Loss: 2.5962
# Train Accuracy: 0.3594, Test Accuracy: 0.3125, Loss: 2.6937
# Train Accuracy: 0.2500, Test Accuracy: 0.3281, Loss: 3.0503
# Train Accuracy: 0.3438, Test Accuracy: 0.2969, Loss: 3.0744
# Train Accuracy: 0.3594, Test Accuracy: 0.3281, Loss: 2.7450
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 3.1709
# Train Accuracy: 0.2031, Test Accuracy: 0.2969, Loss: 3.3540
# Train Accuracy: 0.2031, Test Accuracy: 0.2969, Loss: 2.9863
# Train Accuracy: 0.2656, Test Accuracy: 0.2031, Loss: 3.7950
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 3.3571
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 3.0496
# Train Accuracy: 0.1875, Test Accuracy: 0.2031, Loss: 3.3052
# Train Accuracy: 0.2031, Test Accuracy: 0.2812, Loss: 3.5694
# Train Accuracy: 0.3438, Test Accuracy: 0.2344, Loss: 2.9558
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.3725
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.0418
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 2.7511
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 3.0640
# Train Accuracy: 0.2656, Test Accuracy: 0.3438, Loss: 3.2328
# Train Accuracy: 0.3594, Test Accuracy: 0.3281, Loss: 3.1744
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.0534
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.2864
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.5650
# Train Accuracy: 0.2188, Test Accuracy: 0.2969, Loss: 3.3118
# Train Accuracy: 0.4062, Test Accuracy: 0.2969, Loss: 2.9360
# Train Accuracy: 0.3125, Test Accuracy: 0.3125, Loss: 3.1634
# Train Accuracy: 0.2500, Test Accuracy: 0.2500, Loss: 3.2786
# Train Accuracy: 0.1719, Test Accuracy: 0.3281, Loss: 3.5593
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.3276
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.3406
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.3803
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 3.0612
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 3.4515
# Train Accuracy: 0.2812, Test Accuracy: 0.3438, Loss: 3.1052
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.9935
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.1911
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.8442
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.9094
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.0861
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.0103
# Train Accuracy: 0.3438, Test Accuracy: 0.3281, Loss: 2.9149
# Train Accuracy: 0.4062, Test Accuracy: 0.1875, Loss: 3.0851
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.3858
# Train Accuracy: 0.3125, Test Accuracy: 0.3125, Loss: 3.1565
# Train Accuracy: 0.3594, Test Accuracy: 0.2344, Loss: 2.6255
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.1225
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.2420
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.3781
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.1319
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.4853
# Train Accuracy: 0.1562, Test Accuracy: 0.2812, Loss: 3.7738
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 2.9993
# Train Accuracy: 0.3750, Test Accuracy: 0.3281, Loss: 2.9354
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.4971
# Train Accuracy: 0.1562, Test Accuracy: 0.3438, Loss: 3.6046
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.0772
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.1018
# Train Accuracy: 0.3906, Test Accuracy: 0.2969, Loss: 2.7794
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.0217
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.1090
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.2334
# Train Accuracy: 0.3281, Test Accuracy: 0.2500, Loss: 2.9828
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 3.1934
# Train Accuracy: 0.4219, Test Accuracy: 0.2969, Loss: 3.0484
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.2155
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 2.7887
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.4446
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.2663
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 2.8443
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.6313
# Train Accuracy: 0.3438, Test Accuracy: 0.2344, Loss: 3.2040
# Train Accuracy: 0.4062, Test Accuracy: 0.2656, Loss: 2.9045
# Train Accuracy: 0.3750, Test Accuracy: 0.2500, Loss: 3.2720
# Train Accuracy: 0.3594, Test Accuracy: 0.2812, Loss: 2.7141
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 2.8793
# Train Accuracy: 0.3125, Test Accuracy: 0.3594, Loss: 3.2159
# Train Accuracy: 0.2500, Test Accuracy: 0.2188, Loss: 3.4798
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 3.0877
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.3237
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 3.5022
# Train Accuracy: 0.3125, Test Accuracy: 0.3281, Loss: 3.2347
# Train Accuracy: 0.2031, Test Accuracy: 0.2344, Loss: 3.5741
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.2554
# Train Accuracy: 0.1875, Test Accuracy: 0.2656, Loss: 3.5506
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 3.4658
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 2.9226
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.1320
# Train Accuracy: 0.1875, Test Accuracy: 0.2188, Loss: 3.7550
# Train Accuracy: 0.4062, Test Accuracy: 0.2969, Loss: 2.7783
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.2046
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.3562
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.2071
# Train Accuracy: 0.2031, Test Accuracy: 0.2500, Loss: 3.4346
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 3.2434
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 2.8465
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 2.7776
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.2025
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 3.0271
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 3.1236
# Train Accuracy: 0.1562, Test Accuracy: 0.2500, Loss: 3.6059
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 2.8349
# Train Accuracy: 0.2656, Test Accuracy: 0.1875, Loss: 2.8781
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.0456
# Train Accuracy: 0.4219, Test Accuracy: 0.3125, Loss: 2.5002
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.0626
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.2289
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.1025
# Train Accuracy: 0.2188, Test Accuracy: 0.2188, Loss: 3.3427
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.3423
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.1808
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.3867
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 2.8807
# Train Accuracy: 0.2344, Test Accuracy: 0.3281, Loss: 3.5037
# Train Accuracy: 0.2500, Test Accuracy: 0.3281, Loss: 3.7397
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 2.9859
# Train Accuracy: 0.2344, Test Accuracy: 0.3125, Loss: 3.4876
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.2987
# Train Accuracy: 0.3594, Test Accuracy: 0.3125, Loss: 2.9874
# Train Accuracy: 0.1719, Test Accuracy: 0.3281, Loss: 3.2890
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.7432
# Train Accuracy: 0.3125, Test Accuracy: 0.3281, Loss: 3.1828
# Train Accuracy: 0.3594, Test Accuracy: 0.2812, Loss: 3.0051
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 3.2578
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.0330
# Train Accuracy: 0.3281, Test Accuracy: 0.2344, Loss: 3.3277
# Train Accuracy: 0.2188, Test Accuracy: 0.2500, Loss: 2.9595
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.0119
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.1391
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.2939
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.4898
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.3076
# Train Accuracy: 0.3438, Test Accuracy: 0.3125, Loss: 2.9249
# Train Accuracy: 0.2656, Test Accuracy: 0.3438, Loss: 3.0411
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.0204
# Train Accuracy: 0.3125, Test Accuracy: 0.2188, Loss: 3.3328
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 2.9529
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 2.9579
# Train Accuracy: 0.2969, Test Accuracy: 0.2586, Loss: 3.1521
# Epoch going 45
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.3953
# Train Accuracy: 0.2500, Test Accuracy: 0.3281, Loss: 3.4282
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.3821
# Train Accuracy: 0.1562, Test Accuracy: 0.3125, Loss: 3.3024
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.4381
# Train Accuracy: 0.3438, Test Accuracy: 0.2969, Loss: 3.1747
# Train Accuracy: 0.1719, Test Accuracy: 0.2031, Loss: 3.3060
# Train Accuracy: 0.3594, Test Accuracy: 0.2812, Loss: 2.9866
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.3057
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 2.9981
# Train Accuracy: 0.3594, Test Accuracy: 0.2500, Loss: 2.7612
# Train Accuracy: 0.3750, Test Accuracy: 0.2500, Loss: 2.9661
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.0200
# Train Accuracy: 0.3594, Test Accuracy: 0.2188, Loss: 2.7543
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 2.6860
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.2445
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.1698
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.5911
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.1606
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.4312
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 3.0829
# Train Accuracy: 0.3750, Test Accuracy: 0.2656, Loss: 2.7232
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 3.2061
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 3.1928
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.5403
# Train Accuracy: 0.3281, Test Accuracy: 0.2500, Loss: 2.5747
# Train Accuracy: 0.1875, Test Accuracy: 0.2344, Loss: 3.6798
# Train Accuracy: 0.3750, Test Accuracy: 0.2812, Loss: 2.7942
# Train Accuracy: 0.3750, Test Accuracy: 0.2656, Loss: 2.9619
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.1713
# Train Accuracy: 0.2656, Test Accuracy: 0.4062, Loss: 3.2291
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 2.8294
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.1011
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.3105
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 2.8898
# Train Accuracy: 0.1875, Test Accuracy: 0.2969, Loss: 3.3417
# Train Accuracy: 0.2656, Test Accuracy: 0.2031, Loss: 3.7015
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 3.0692
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 3.1815
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 2.5749
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.3143
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 3.0148
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.2996
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 2.9603
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.1889
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 2.9954
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.4255
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 2.8690
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 3.2851
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 2.7951
# Train Accuracy: 0.1875, Test Accuracy: 0.2656, Loss: 3.4003
# Train Accuracy: 0.2031, Test Accuracy: 0.2656, Loss: 3.2389
# Train Accuracy: 0.3438, Test Accuracy: 0.2812, Loss: 2.9390
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.1694
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.3217
# Train Accuracy: 0.1875, Test Accuracy: 0.2344, Loss: 3.2427
# Train Accuracy: 0.3750, Test Accuracy: 0.3906, Loss: 3.5021
# Train Accuracy: 0.2656, Test Accuracy: 0.3438, Loss: 2.9834
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.2113
# Train Accuracy: 0.2031, Test Accuracy: 0.2656, Loss: 3.4539
# Train Accuracy: 0.2500, Test Accuracy: 0.2500, Loss: 3.2904
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.3468
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 3.3049
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.2146
# Train Accuracy: 0.2500, Test Accuracy: 0.3281, Loss: 3.4462
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 2.8346
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.5278
# Train Accuracy: 0.2500, Test Accuracy: 0.2344, Loss: 3.3045
# Train Accuracy: 0.2812, Test Accuracy: 0.3281, Loss: 3.8575
# Train Accuracy: 0.3125, Test Accuracy: 0.2969, Loss: 2.9579
# Train Accuracy: 0.3281, Test Accuracy: 0.2344, Loss: 3.0897
# Train Accuracy: 0.2188, Test Accuracy: 0.3281, Loss: 3.5348
# Train Accuracy: 0.1562, Test Accuracy: 0.2656, Loss: 3.5701
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.0122
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.4163
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.3886
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 3.1052
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 2.8673
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.2852
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.1761
# Train Accuracy: 0.1719, Test Accuracy: 0.2812, Loss: 3.4188
# Train Accuracy: 0.2812, Test Accuracy: 0.3281, Loss: 3.2511
# Train Accuracy: 0.1875, Test Accuracy: 0.3281, Loss: 3.4212
# Train Accuracy: 0.1875, Test Accuracy: 0.2969, Loss: 3.4437
# Train Accuracy: 0.2500, Test Accuracy: 0.2500, Loss: 3.4682
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.8521
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 3.0358
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 3.2491
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.0428
# Train Accuracy: 0.1719, Test Accuracy: 0.2500, Loss: 3.5444
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 2.9670
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.1228
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.8498
# Train Accuracy: 0.2812, Test Accuracy: 0.1875, Loss: 3.0806
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.4631
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.5455
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.3341
# Train Accuracy: 0.3594, Test Accuracy: 0.2344, Loss: 3.0122
# Train Accuracy: 0.2812, Test Accuracy: 0.2344, Loss: 3.2360
# Train Accuracy: 0.2031, Test Accuracy: 0.3281, Loss: 3.5654
# Train Accuracy: 0.3750, Test Accuracy: 0.2656, Loss: 2.5625
# Train Accuracy: 0.2031, Test Accuracy: 0.3125, Loss: 3.3818
# Train Accuracy: 0.3594, Test Accuracy: 0.3125, Loss: 3.1816
# Train Accuracy: 0.2188, Test Accuracy: 0.2188, Loss: 3.4690
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 2.8430
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.2059
# Train Accuracy: 0.3125, Test Accuracy: 0.2031, Loss: 3.1342
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.2352
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 3.6582
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 3.3343
# Train Accuracy: 0.2031, Test Accuracy: 0.2188, Loss: 3.2194
# Train Accuracy: 0.2812, Test Accuracy: 0.2344, Loss: 3.4627
# Train Accuracy: 0.2500, Test Accuracy: 0.1562, Loss: 3.1078
# Train Accuracy: 0.3125, Test Accuracy: 0.2188, Loss: 3.4827
# Train Accuracy: 0.2344, Test Accuracy: 0.0938, Loss: 3.4834
# Train Accuracy: 0.3594, Test Accuracy: 0.1562, Loss: 3.2478
# Train Accuracy: 0.2031, Test Accuracy: 0.1094, Loss: 3.6083
# Train Accuracy: 0.3125, Test Accuracy: 0.1562, Loss: 3.4227
# Train Accuracy: 0.3438, Test Accuracy: 0.1719, Loss: 3.0249
# Train Accuracy: 0.3594, Test Accuracy: 0.0938, Loss: 2.9892
# Train Accuracy: 0.2656, Test Accuracy: 0.1562, Loss: 3.2141
# Train Accuracy: 0.3438, Test Accuracy: 0.2969, Loss: 2.9670
# Train Accuracy: 0.2188, Test Accuracy: 0.5000, Loss: 3.3453
# Train Accuracy: 0.2344, Test Accuracy: 0.5000, Loss: 3.2458
# Train Accuracy: 0.3594, Test Accuracy: 0.3906, Loss: 2.8387
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.3266
# Train Accuracy: 0.3594, Test Accuracy: 0.3750, Loss: 3.3145
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 3.4751
# Train Accuracy: 0.3281, Test Accuracy: 0.4531, Loss: 3.1661
# Train Accuracy: 0.2656, Test Accuracy: 0.4688, Loss: 3.1663
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.0717
# Train Accuracy: 0.1562, Test Accuracy: 0.0938, Loss: 3.5679
# Train Accuracy: 0.1719, Test Accuracy: 0.0000, Loss: 3.5852
# Train Accuracy: 0.2344, Test Accuracy: 0.0156, Loss: 3.2048
# Train Accuracy: 0.2812, Test Accuracy: 0.0156, Loss: 2.7725
# Train Accuracy: 0.2344, Test Accuracy: 0.0000, Loss: 3.5302
# Train Accuracy: 0.3750, Test Accuracy: 0.0312, Loss: 2.9026
# Train Accuracy: 0.3438, Test Accuracy: 0.0156, Loss: 3.1507
# Train Accuracy: 0.2188, Test Accuracy: 0.0156, Loss: 3.3109
# Train Accuracy: 0.3281, Test Accuracy: 0.0000, Loss: 3.1999
# Train Accuracy: 0.2344, Test Accuracy: 0.0156, Loss: 2.9654
# Train Accuracy: 0.3438, Test Accuracy: 0.0156, Loss: 3.1776
# Train Accuracy: 0.2812, Test Accuracy: 0.0156, Loss: 3.1022
# Train Accuracy: 0.3281, Test Accuracy: 0.0000, Loss: 3.2646
# Train Accuracy: 0.3125, Test Accuracy: 0.0156, Loss: 3.3846
# Train Accuracy: 0.3594, Test Accuracy: 0.0000, Loss: 2.9587
# Train Accuracy: 0.1875, Test Accuracy: 0.0156, Loss: 3.3624
# Train Accuracy: 0.1875, Test Accuracy: 0.0156, Loss: 3.1962
# Train Accuracy: 0.2500, Test Accuracy: 0.0312, Loss: 3.3449
# Train Accuracy: 0.3281, Test Accuracy: 0.0000, Loss: 3.4483
# Train Accuracy: 0.2656, Test Accuracy: 0.0469, Loss: 3.2441
# Train Accuracy: 0.2344, Test Accuracy: 0.0469, Loss: 3.5385
# Train Accuracy: 0.2500, Test Accuracy: 0.0000, Loss: 3.2433
# Train Accuracy: 0.2969, Test Accuracy: 0.0156, Loss: 2.8489
# Train Accuracy: 0.3438, Test Accuracy: 0.0000, Loss: 3.2247
# Train Accuracy: 0.3594, Test Accuracy: 0.0156, Loss: 2.8131
# Train Accuracy: 0.3125, Test Accuracy: 0.0156, Loss: 3.4000
# Train Accuracy: 0.3125, Test Accuracy: 0.0156, Loss: 3.0021
# Train Accuracy: 0.2656, Test Accuracy: 0.0156, Loss: 3.3853
# Train Accuracy: 0.2656, Test Accuracy: 0.0000, Loss: 3.3424
# Train Accuracy: 0.2344, Test Accuracy: 0.0156, Loss: 3.1506
# Train Accuracy: 0.2188, Test Accuracy: 0.0469, Loss: 3.3957
# Train Accuracy: 0.2500, Test Accuracy: 0.0000, Loss: 3.4304
# Train Accuracy: 0.3281, Test Accuracy: 0.0000, Loss: 3.0256
# Train Accuracy: 0.2969, Test Accuracy: 0.0000, Loss: 3.1811
# Train Accuracy: 0.2344, Test Accuracy: 0.0312, Loss: 3.4089
# Train Accuracy: 0.2344, Test Accuracy: 0.0000, Loss: 3.0707
# Train Accuracy: 0.2656, Test Accuracy: 0.0625, Loss: 3.1699
# Train Accuracy: 0.2656, Test Accuracy: 0.0000, Loss: 2.9081
# Train Accuracy: 0.2969, Test Accuracy: 0.0000, Loss: 3.3108
# Train Accuracy: 0.2969, Test Accuracy: 0.0000, Loss: 3.0303
# Train Accuracy: 0.2969, Test Accuracy: 0.1094, Loss: 3.1607
# Train Accuracy: 0.2656, Test Accuracy: 0.0312, Loss: 3.2483
# Train Accuracy: 0.2031, Test Accuracy: 0.0625, Loss: 3.4767
# Train Accuracy: 0.2031, Test Accuracy: 0.0781, Loss: 3.6197
# Train Accuracy: 0.3125, Test Accuracy: 0.0625, Loss: 2.8830
# Train Accuracy: 0.2031, Test Accuracy: 0.0469, Loss: 3.3343
# Train Accuracy: 0.2188, Test Accuracy: 0.0469, Loss: 3.4480
# Train Accuracy: 0.2344, Test Accuracy: 0.0469, Loss: 3.3434
# Train Accuracy: 0.2188, Test Accuracy: 0.0781, Loss: 3.8390
# Train Accuracy: 0.3125, Test Accuracy: 0.1875, Loss: 3.0521
# Train Accuracy: 0.2969, Test Accuracy: 0.1094, Loss: 3.3021
# Train Accuracy: 0.2656, Test Accuracy: 0.1250, Loss: 3.2146
# Train Accuracy: 0.2500, Test Accuracy: 0.0625, Loss: 3.2330
# Train Accuracy: 0.3438, Test Accuracy: 0.0938, Loss: 3.0312
# Train Accuracy: 0.2500, Test Accuracy: 0.1719, Loss: 3.4459
# Train Accuracy: 0.2969, Test Accuracy: 0.0625, Loss: 2.9805
# Train Accuracy: 0.2969, Test Accuracy: 0.0469, Loss: 2.9892
# Train Accuracy: 0.3438, Test Accuracy: 0.1094, Loss: 3.0714
# Train Accuracy: 0.4219, Test Accuracy: 0.1094, Loss: 3.0930
# Train Accuracy: 0.2500, Test Accuracy: 0.0625, Loss: 3.5648
# Train Accuracy: 0.2500, Test Accuracy: 0.1094, Loss: 3.3628
# Train Accuracy: 0.3906, Test Accuracy: 0.1250, Loss: 2.9838
# Train Accuracy: 0.2344, Test Accuracy: 0.0469, Loss: 3.1600
# Train Accuracy: 0.2188, Test Accuracy: 0.0625, Loss: 3.5850
# Train Accuracy: 0.2656, Test Accuracy: 0.1406, Loss: 3.2098
# Train Accuracy: 0.2500, Test Accuracy: 0.0938, Loss: 3.3712
# Train Accuracy: 0.2656, Test Accuracy: 0.0781, Loss: 3.1418
# Train Accuracy: 0.2031, Test Accuracy: 0.1094, Loss: 3.7827
# Train Accuracy: 0.2656, Test Accuracy: 0.1406, Loss: 2.9993
# Train Accuracy: 0.2812, Test Accuracy: 0.0781, Loss: 3.3487
# Train Accuracy: 0.2031, Test Accuracy: 0.0625, Loss: 3.3864
# Train Accuracy: 0.3125, Test Accuracy: 0.1250, Loss: 3.1121
# Train Accuracy: 0.2031, Test Accuracy: 0.1094, Loss: 3.4974
# Train Accuracy: 0.2656, Test Accuracy: 0.0781, Loss: 3.4570
# Train Accuracy: 0.3125, Test Accuracy: 0.0938, Loss: 3.4164
# Train Accuracy: 0.2969, Test Accuracy: 0.1406, Loss: 3.0168
# Train Accuracy: 0.2344, Test Accuracy: 0.0625, Loss: 3.5501
# Train Accuracy: 0.3125, Test Accuracy: 0.0469, Loss: 2.9996
# Train Accuracy: 0.3125, Test Accuracy: 0.1406, Loss: 3.0048
# Train Accuracy: 0.2969, Test Accuracy: 0.0781, Loss: 3.4237
# Train Accuracy: 0.2812, Test Accuracy: 0.0469, Loss: 3.0414
# Train Accuracy: 0.2344, Test Accuracy: 0.1406, Loss: 3.4485
# Train Accuracy: 0.2656, Test Accuracy: 0.1094, Loss: 3.2134
# Train Accuracy: 0.3438, Test Accuracy: 0.0625, Loss: 3.1843
# Train Accuracy: 0.2344, Test Accuracy: 0.0781, Loss: 3.5204
# Train Accuracy: 0.2656, Test Accuracy: 0.1250, Loss: 3.0995
# Train Accuracy: 0.2344, Test Accuracy: 0.0938, Loss: 3.3594
# Train Accuracy: 0.2656, Test Accuracy: 0.0469, Loss: 3.5044
# Train Accuracy: 0.2812, Test Accuracy: 0.1094, Loss: 3.4009
# Train Accuracy: 0.2500, Test Accuracy: 0.1094, Loss: 2.7875
# Train Accuracy: 0.2344, Test Accuracy: 0.0312, Loss: 3.3649
# Train Accuracy: 0.2812, Test Accuracy: 0.0625, Loss: 3.2570
# Train Accuracy: 0.1875, Test Accuracy: 0.1875, Loss: 3.2330
# Train Accuracy: 0.2500, Test Accuracy: 0.1094, Loss: 3.0753
# Train Accuracy: 0.1719, Test Accuracy: 0.0469, Loss: 3.3367
# Train Accuracy: 0.2500, Test Accuracy: 0.1094, Loss: 3.4123
# Train Accuracy: 0.2969, Test Accuracy: 0.0781, Loss: 3.1216
# Train Accuracy: 0.2188, Test Accuracy: 0.0312, Loss: 3.4059
# Train Accuracy: 0.2969, Test Accuracy: 0.1094, Loss: 3.2140
# Train Accuracy: 0.3750, Test Accuracy: 0.1406, Loss: 2.8311
# Train Accuracy: 0.3125, Test Accuracy: 0.0781, Loss: 2.9862
# Train Accuracy: 0.3125, Test Accuracy: 0.0938, Loss: 3.2618
# Train Accuracy: 0.2344, Test Accuracy: 0.1406, Loss: 3.2753
# Train Accuracy: 0.3125, Test Accuracy: 0.0781, Loss: 3.3330
# Train Accuracy: 0.4062, Test Accuracy: 0.1094, Loss: 3.0008
# Train Accuracy: 0.3125, Test Accuracy: 0.1250, Loss: 3.1009
# Train Accuracy: 0.2500, Test Accuracy: 0.1250, Loss: 3.2460
# Train Accuracy: 0.2188, Test Accuracy: 0.1094, Loss: 3.3704
# Train Accuracy: 0.2656, Test Accuracy: 0.0469, Loss: 2.9713
# Train Accuracy: 0.2969, Test Accuracy: 0.1250, Loss: 3.0357
# Train Accuracy: 0.2188, Test Accuracy: 0.0625, Loss: 3.4370
# Train Accuracy: 0.2500, Test Accuracy: 0.0781, Loss: 3.0763
# Train Accuracy: 0.2812, Test Accuracy: 0.1250, Loss: 2.9231
# Train Accuracy: 0.3438, Test Accuracy: 0.1094, Loss: 3.1556
# Train Accuracy: 0.2500, Test Accuracy: 0.0312, Loss: 3.1416
# Train Accuracy: 0.3906, Test Accuracy: 0.1406, Loss: 2.9484
# Train Accuracy: 0.3438, Test Accuracy: 0.1250, Loss: 3.2616
# Train Accuracy: 0.2969, Test Accuracy: 0.0625, Loss: 2.9567
# Train Accuracy: 0.2031, Test Accuracy: 0.0781, Loss: 3.5139
# Train Accuracy: 0.3281, Test Accuracy: 0.1250, Loss: 3.0934
# Train Accuracy: 0.2969, Test Accuracy: 0.0938, Loss: 3.0683
# Train Accuracy: 0.2656, Test Accuracy: 0.0469, Loss: 3.1660
# Train Accuracy: 0.2969, Test Accuracy: 0.1250, Loss: 3.0537
# Train Accuracy: 0.2969, Test Accuracy: 0.1250, Loss: 3.3815
# Train Accuracy: 0.3281, Test Accuracy: 0.0625, Loss: 2.7392
# Train Accuracy: 0.2656, Test Accuracy: 0.0938, Loss: 3.7539
# Train Accuracy: 0.3906, Test Accuracy: 0.1406, Loss: 2.8437
# Train Accuracy: 0.2969, Test Accuracy: 0.0625, Loss: 2.8975
# Train Accuracy: 0.2344, Test Accuracy: 0.0469, Loss: 3.2391
# Train Accuracy: 0.2656, Test Accuracy: 0.1250, Loss: 3.5073
# Train Accuracy: 0.2656, Test Accuracy: 0.0938, Loss: 3.2101
# Train Accuracy: 0.2500, Test Accuracy: 0.0625, Loss: 3.0115
# Train Accuracy: 0.4062, Test Accuracy: 0.0938, Loss: 2.6399
# Train Accuracy: 0.2344, Test Accuracy: 0.1406, Loss: 3.4869
# Train Accuracy: 0.2031, Test Accuracy: 0.0625, Loss: 3.1949
# Train Accuracy: 0.2188, Test Accuracy: 0.0469, Loss: 3.5069
# Train Accuracy: 0.2031, Test Accuracy: 0.1094, Loss: 3.4492
# Train Accuracy: 0.2812, Test Accuracy: 0.1406, Loss: 3.4632
# Train Accuracy: 0.2031, Test Accuracy: 0.0625, Loss: 3.6172
# Train Accuracy: 0.2812, Test Accuracy: 0.1250, Loss: 3.1272
# Train Accuracy: 0.2344, Test Accuracy: 0.1250, Loss: 3.2434
# Train Accuracy: 0.3594, Test Accuracy: 0.0625, Loss: 3.4211
# Train Accuracy: 0.2812, Test Accuracy: 0.0625, Loss: 3.2029
# Train Accuracy: 0.2656, Test Accuracy: 0.1562, Loss: 3.2676
# Train Accuracy: 0.3125, Test Accuracy: 0.1250, Loss: 3.0142
# Train Accuracy: 0.2656, Test Accuracy: 0.0781, Loss: 3.4932
# Train Accuracy: 0.3281, Test Accuracy: 0.1094, Loss: 3.0687
# Train Accuracy: 0.3281, Test Accuracy: 0.0938, Loss: 3.1174
# Train Accuracy: 0.3438, Test Accuracy: 0.1094, Loss: 3.1708
# Train Accuracy: 0.2656, Test Accuracy: 0.1250, Loss: 3.3839
# Train Accuracy: 0.2656, Test Accuracy: 0.0781, Loss: 3.5324
# Train Accuracy: 0.2031, Test Accuracy: 0.0156, Loss: 3.1626
# Train Accuracy: 0.2188, Test Accuracy: 0.0781, Loss: 3.4360
# Train Accuracy: 0.2656, Test Accuracy: 0.0000, Loss: 3.1692
# Train Accuracy: 0.2812, Test Accuracy: 0.0469, Loss: 3.5201
# Train Accuracy: 0.3594, Test Accuracy: 0.0938, Loss: 3.0514
# Train Accuracy: 0.2344, Test Accuracy: 0.0625, Loss: 3.3670
# Train Accuracy: 0.3438, Test Accuracy: 0.0625, Loss: 2.9170
# Train Accuracy: 0.1875, Test Accuracy: 0.0469, Loss: 3.7577
# Train Accuracy: 0.3281, Test Accuracy: 0.0625, Loss: 3.4814
# Train Accuracy: 0.2969, Test Accuracy: 0.1094, Loss: 2.9813
# Train Accuracy: 0.4219, Test Accuracy: 0.0156, Loss: 2.8223
# Train Accuracy: 0.3438, Test Accuracy: 0.0625, Loss: 2.7252
# Train Accuracy: 0.1719, Test Accuracy: 0.0469, Loss: 3.6938
# Train Accuracy: 0.4062, Test Accuracy: 0.0781, Loss: 2.5594
# Train Accuracy: 0.3281, Test Accuracy: 0.0781, Loss: 2.8656
# Train Accuracy: 0.2812, Test Accuracy: 0.1719, Loss: 3.0516
# Train Accuracy: 0.2656, Test Accuracy: 0.2031, Loss: 2.7465
# Train Accuracy: 0.2969, Test Accuracy: 0.1719, Loss: 3.2141
# Train Accuracy: 0.2031, Test Accuracy: 0.0469, Loss: 3.3634
# Train Accuracy: 0.2969, Test Accuracy: 0.1719, Loss: 2.9539
# Train Accuracy: 0.3125, Test Accuracy: 0.1719, Loss: 2.9983
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.4685
# Train Accuracy: 0.2500, Test Accuracy: 0.1875, Loss: 3.4962
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 3.0461
# Train Accuracy: 0.1875, Test Accuracy: 0.2188, Loss: 3.5322
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 2.9095
# Train Accuracy: 0.2500, Test Accuracy: 0.4531, Loss: 3.6213
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 3.2434
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 2.7042
# Train Accuracy: 0.3594, Test Accuracy: 0.4219, Loss: 2.9157
# Train Accuracy: 0.2031, Test Accuracy: 0.4531, Loss: 3.0958
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.0287
# Train Accuracy: 0.3281, Test Accuracy: 0.4375, Loss: 3.1205
# Train Accuracy: 0.1875, Test Accuracy: 0.3906, Loss: 3.2028
# Train Accuracy: 0.1875, Test Accuracy: 0.3750, Loss: 3.5180
# Train Accuracy: 0.1719, Test Accuracy: 0.4375, Loss: 3.0367
# Train Accuracy: 0.3281, Test Accuracy: 0.4219, Loss: 3.1713
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 2.9886
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.0155
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.4351
# Train Accuracy: 0.3438, Test Accuracy: 0.4219, Loss: 3.2475
# Train Accuracy: 0.2188, Test Accuracy: 0.4062, Loss: 3.6677
# Train Accuracy: 0.2344, Test Accuracy: 0.4688, Loss: 3.1480
# Train Accuracy: 0.3750, Test Accuracy: 0.3906, Loss: 2.9963
# Train Accuracy: 0.2031, Test Accuracy: 0.4688, Loss: 3.4981
# Train Accuracy: 0.2500, Test Accuracy: 0.4375, Loss: 3.1643
# Train Accuracy: 0.2656, Test Accuracy: 0.3594, Loss: 3.1273
# Train Accuracy: 0.2344, Test Accuracy: 0.4531, Loss: 2.8565
# Train Accuracy: 0.2344, Test Accuracy: 0.4219, Loss: 3.5133
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 3.3400
# Train Accuracy: 0.2969, Test Accuracy: 0.4531, Loss: 3.0811
# Train Accuracy: 0.2656, Test Accuracy: 0.4531, Loss: 3.2196
# Train Accuracy: 0.1875, Test Accuracy: 0.3906, Loss: 3.2085
# Train Accuracy: 0.3594, Test Accuracy: 0.4219, Loss: 3.0293
# Train Accuracy: 0.2969, Test Accuracy: 0.4375, Loss: 3.2975
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.5554
# Train Accuracy: 0.2500, Test Accuracy: 0.4531, Loss: 3.5452
# Train Accuracy: 0.3125, Test Accuracy: 0.4844, Loss: 3.2375
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 3.1647
# Train Accuracy: 0.2500, Test Accuracy: 0.4219, Loss: 3.2393
# Train Accuracy: 0.1875, Test Accuracy: 0.4219, Loss: 3.4174
# Train Accuracy: 0.3438, Test Accuracy: 0.4375, Loss: 3.0284
# Train Accuracy: 0.3125, Test Accuracy: 0.4531, Loss: 3.1484
# Train Accuracy: 0.3438, Test Accuracy: 0.4375, Loss: 2.8423
# Train Accuracy: 0.2969, Test Accuracy: 0.4219, Loss: 3.1208
# Train Accuracy: 0.2656, Test Accuracy: 0.4219, Loss: 3.1991
# Train Accuracy: 0.2969, Test Accuracy: 0.4531, Loss: 3.0703
# Train Accuracy: 0.2812, Test Accuracy: 0.3594, Loss: 2.9594
# Train Accuracy: 0.3281, Test Accuracy: 0.4375, Loss: 3.0225
# Train Accuracy: 0.2031, Test Accuracy: 0.4688, Loss: 3.3980
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.1927
# Train Accuracy: 0.3281, Test Accuracy: 0.4219, Loss: 3.0026
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 3.3947
# Train Accuracy: 0.2969, Test Accuracy: 0.4375, Loss: 3.3353
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 2.6388
# Train Accuracy: 0.2500, Test Accuracy: 0.4375, Loss: 3.3011
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 2.8025
# Train Accuracy: 0.1875, Test Accuracy: 0.4062, Loss: 3.5490
# Train Accuracy: 0.2969, Test Accuracy: 0.4688, Loss: 3.1575
# Train Accuracy: 0.3594, Test Accuracy: 0.3750, Loss: 3.4555
# Train Accuracy: 0.2500, Test Accuracy: 0.4062, Loss: 3.1584
# Train Accuracy: 0.3281, Test Accuracy: 0.4688, Loss: 3.2237
# Train Accuracy: 0.2344, Test Accuracy: 0.4219, Loss: 3.4085
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 2.8877
# Train Accuracy: 0.2812, Test Accuracy: 0.4531, Loss: 3.1351
# Train Accuracy: 0.3281, Test Accuracy: 0.4219, Loss: 2.9199
# Train Accuracy: 0.3594, Test Accuracy: 0.4531, Loss: 2.9618
# Train Accuracy: 0.2500, Test Accuracy: 0.4531, Loss: 3.2275
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 3.5533
# Train Accuracy: 0.2812, Test Accuracy: 0.4375, Loss: 3.3579
# Train Accuracy: 0.2188, Test Accuracy: 0.4375, Loss: 3.4433
# Train Accuracy: 0.2812, Test Accuracy: 0.4219, Loss: 2.8807
# Train Accuracy: 0.2500, Test Accuracy: 0.4219, Loss: 3.1925
# Train Accuracy: 0.1875, Test Accuracy: 0.4531, Loss: 3.1587
# Train Accuracy: 0.3125, Test Accuracy: 0.4375, Loss: 2.8940
# Train Accuracy: 0.3125, Test Accuracy: 0.4219, Loss: 2.9135
# Train Accuracy: 0.4062, Test Accuracy: 0.4219, Loss: 2.7366
# ...
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.1450
# Train Accuracy: 0.2656, Test Accuracy: 0.3750, Loss: 2.9746
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.4925
# Train Accuracy: 0.2500, Test Accuracy: 0.3594, Loss: 3.2067
# Train Accuracy: 0.1719, Test Accuracy: 0.4062, Loss: 3.9943
# Train Accuracy: 0.2656, Test Accuracy: 0.4219, Loss: 3.3484
# Train Accuracy: 0.2812, Test Accuracy: 0.3906, Loss: 3.0945
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 3.1159
# Train Accuracy: 0.3750, Test Accuracy: 0.3750, Loss: 2.9292
# Train Accuracy: 0.2656, Test Accuracy: 0.3906, Loss: 3.2207
# Train Accuracy: 0.3594, Test Accuracy: 0.4062, Loss: 2.9556
# Train Accuracy: 0.2812, Test Accuracy: 0.3750, Loss: 3.0730
# Train Accuracy: 0.3281, Test Accuracy: 0.3906, Loss: 3.1464
# Train Accuracy: 0.3125, Test Accuracy: 0.4062, Loss: 3.0568
# Train Accuracy: 0.1719, Test Accuracy: 0.3906, Loss: 3.5936
# Train Accuracy: 0.3750, Test Accuracy: 0.3438, Loss: 3.0492
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.3146
# Train Accuracy: 0.2969, Test Accuracy: 0.3906, Loss: 3.2071
# Train Accuracy: 0.2656, Test Accuracy: 0.3750, Loss: 3.3285
# Train Accuracy: 0.2812, Test Accuracy: 0.4062, Loss: 3.0673
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 3.1750
# Train Accuracy: 0.3125, Test Accuracy: 0.3906, Loss: 3.1453
# Train Accuracy: 0.3438, Test Accuracy: 0.4062, Loss: 3.1365
# Train Accuracy: 0.3125, Test Accuracy: 0.4062, Loss: 3.0655
# Train Accuracy: 0.1875, Test Accuracy: 0.4062, Loss: 3.6399
# Train Accuracy: 0.2969, Test Accuracy: 0.4062, Loss: 3.1646
# Train Accuracy: 0.1875, Test Accuracy: 0.3906, Loss: 3.3401
# Train Accuracy: 0.2812, Test Accuracy: 0.3750, Loss: 3.1517
# Train Accuracy: 0.3281, Test Accuracy: 0.4062, Loss: 3.1903
# Train Accuracy: 0.2500, Test Accuracy: 0.3750, Loss: 3.2321
# Train Accuracy: 0.3281, Test Accuracy: 0.3750, Loss: 2.7881
# Train Accuracy: 0.2344, Test Accuracy: 0.5781, Loss: 3.2555
# Train Accuracy: 0.3906, Test Accuracy: 0.3594, Loss: 3.2929
# Train Accuracy: 0.3438, Test Accuracy: 0.1406, Loss: 3.2809
# Train Accuracy: 0.2344, Test Accuracy: 0.1562, Loss: 3.1673
# Train Accuracy: 0.2812, Test Accuracy: 0.1875, Loss: 3.7189
# Train Accuracy: 0.2969, Test Accuracy: 0.1562, Loss: 3.1754
# Train Accuracy: 0.3281, Test Accuracy: 0.2031, Loss: 2.9837
# Train Accuracy: 0.1875, Test Accuracy: 0.1719, Loss: 3.6834
# Train Accuracy: 0.2969, Test Accuracy: 0.1406, Loss: 3.4011
# Train Accuracy: 0.2656, Test Accuracy: 0.1406, Loss: 3.3934
# Train Accuracy: 0.3438, Test Accuracy: 0.2188, Loss: 3.0401
# Train Accuracy: 0.2500, Test Accuracy: 0.1875, Loss: 3.3751
# Train Accuracy: 0.3594, Test Accuracy: 0.1875, Loss: 2.8462
# Train Accuracy: 0.2969, Test Accuracy: 0.1719, Loss: 3.2315
# Train Accuracy: 0.3594, Test Accuracy: 0.1094, Loss: 2.8770
# Train Accuracy: 0.3750, Test Accuracy: 0.2500, Loss: 2.9502
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.3738
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.1713
# Train Accuracy: 0.2344, Test Accuracy: 0.1719, Loss: 3.2697
# Train Accuracy: 0.3594, Test Accuracy: 0.1875, Loss: 2.6886
# Train Accuracy: 0.2656, Test Accuracy: 0.1875, Loss: 3.0114
# Train Accuracy: 0.2188, Test Accuracy: 0.2031, Loss: 3.0583
# Train Accuracy: 0.3438, Test Accuracy: 0.2188, Loss: 2.6041
# Train Accuracy: 0.2656, Test Accuracy: 0.3125, Loss: 2.9803
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 3.3179
# Train Accuracy: 0.3125, Test Accuracy: 0.1719, Loss: 3.2631
# Train Accuracy: 0.2969, Test Accuracy: 0.1719, Loss: 3.1662
# Train Accuracy: 0.3750, Test Accuracy: 0.1875, Loss: 2.7286
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 3.2023
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.1866
# Train Accuracy: 0.2344, Test Accuracy: 0.2031, Loss: 3.5026
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 3.5857
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.2970
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.2649
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.2734
# Train Accuracy: 0.1875, Test Accuracy: 0.2969, Loss: 3.5809
# Train Accuracy: 0.1719, Test Accuracy: 0.2344, Loss: 3.5710
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.5089
# Train Accuracy: 0.3594, Test Accuracy: 0.2656, Loss: 2.9730
# Train Accuracy: 0.2969, Test Accuracy: 0.2188, Loss: 3.2046
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.4016
# Train Accuracy: 0.3750, Test Accuracy: 0.2188, Loss: 3.2307
# Train Accuracy: 0.2500, Test Accuracy: 0.2031, Loss: 3.1723
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.1749
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.1813
# Train Accuracy: 0.3125, Test Accuracy: 0.2188, Loss: 3.1970
# Train Accuracy: 0.2031, Test Accuracy: 0.3125, Loss: 3.5321
# Train Accuracy: 0.2344, Test Accuracy: 0.2188, Loss: 3.1883
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.0214
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.4159
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.1837
# Train Accuracy: 0.2344, Test Accuracy: 0.2812, Loss: 2.9926
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 3.0298
# Train Accuracy: 0.2344, Test Accuracy: 0.3594, Loss: 3.1904
# Train Accuracy: 0.2188, Test Accuracy: 0.1875, Loss: 3.3566
# Train Accuracy: 0.2188, Test Accuracy: 0.2500, Loss: 3.7746
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.1394
# Train Accuracy: 0.2812, Test Accuracy: 0.2344, Loss: 3.3185
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.3112
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 3.2766
# Train Accuracy: 0.3594, Test Accuracy: 0.2500, Loss: 3.3384
# Train Accuracy: 0.3281, Test Accuracy: 0.2188, Loss: 3.0050
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.2582
# Train Accuracy: 0.2031, Test Accuracy: 0.2500, Loss: 3.4009
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.1548
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.0317
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.3775
# Train Accuracy: 0.3125, Test Accuracy: 0.3125, Loss: 2.9457
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.4173
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 2.9352
# Train Accuracy: 0.4219, Test Accuracy: 0.2812, Loss: 2.8334
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 2.9519
# Train Accuracy: 0.2344, Test Accuracy: 0.2344, Loss: 3.6442
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 2.9036
# Train Accuracy: 0.2188, Test Accuracy: 0.2188, Loss: 3.3848
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 3.1018
# Train Accuracy: 0.3125, Test Accuracy: 0.2344, Loss: 2.7792
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.6387
# Train Accuracy: 0.1875, Test Accuracy: 0.2344, Loss: 3.6463
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.5097
# Train Accuracy: 0.2031, Test Accuracy: 0.2188, Loss: 3.3755
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 3.0627
# Train Accuracy: 0.2344, Test Accuracy: 0.2500, Loss: 3.4264
# Train Accuracy: 0.2344, Test Accuracy: 0.2500, Loss: 3.5113
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.2620
# Train Accuracy: 0.1875, Test Accuracy: 0.2812, Loss: 3.3981
# Train Accuracy: 0.3281, Test Accuracy: 0.2188, Loss: 2.9909
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.2839
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 3.8842
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.2420
# Train Accuracy: 0.3750, Test Accuracy: 0.2812, Loss: 2.8183
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.1280
# Train Accuracy: 0.2188, Test Accuracy: 0.2656, Loss: 3.1110
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.2971
# Train Accuracy: 0.3125, Test Accuracy: 0.2812, Loss: 2.9344
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.2814
# Train Accuracy: 0.3125, Test Accuracy: 0.3125, Loss: 3.2328
# Train Accuracy: 0.3438, Test Accuracy: 0.2656, Loss: 3.0479
# Train Accuracy: 0.3438, Test Accuracy: 0.3125, Loss: 3.1893
# Train Accuracy: 0.2812, Test Accuracy: 0.3281, Loss: 3.1943
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.5825
# Train Accuracy: 0.3125, Test Accuracy: 0.3281, Loss: 3.2084
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.1764
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.1476
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 2.8639
# Train Accuracy: 0.4062, Test Accuracy: 0.2031, Loss: 2.8918
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 3.1481
# Train Accuracy: 0.2812, Test Accuracy: 0.2969, Loss: 3.1151
# Train Accuracy: 0.2500, Test Accuracy: 0.2031, Loss: 2.9585
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.2000
# Train Accuracy: 0.3594, Test Accuracy: 0.2344, Loss: 3.0524
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 3.2992
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.3915
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 2.7372
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 2.8342
# Train Accuracy: 0.3281, Test Accuracy: 0.3281, Loss: 2.7472
# Train Accuracy: 0.3281, Test Accuracy: 0.3281, Loss: 2.8280
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 3.1211
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.4129
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 3.1828
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.3573
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.2231
# Train Accuracy: 0.2656, Test Accuracy: 0.3125, Loss: 3.3042
# Train Accuracy: 0.2344, Test Accuracy: 0.2500, Loss: 3.3411
# Train Accuracy: 0.1875, Test Accuracy: 0.3281, Loss: 3.4456
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.0354
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.4955
# Train Accuracy: 0.1875, Test Accuracy: 0.2812, Loss: 3.5566
# Train Accuracy: 0.2031, Test Accuracy: 0.2656, Loss: 2.8930
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.2845
# Train Accuracy: 0.2500, Test Accuracy: 0.3281, Loss: 3.4916
# Train Accuracy: 0.2031, Test Accuracy: 0.2344, Loss: 3.4957
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 2.9726
# Train Accuracy: 0.3438, Test Accuracy: 0.2969, Loss: 3.0830
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.2202
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.2975
# Train Accuracy: 0.1875, Test Accuracy: 0.2500, Loss: 3.4381
# Train Accuracy: 0.2031, Test Accuracy: 0.3438, Loss: 3.7011
# Train Accuracy: 0.3125, Test Accuracy: 0.1875, Loss: 2.8667
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 2.9445
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 2.9415
# Train Accuracy: 0.2188, Test Accuracy: 0.2500, Loss: 3.2632
# Train Accuracy: 0.2500, Test Accuracy: 0.2812, Loss: 2.8069
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 2.8384
# Train Accuracy: 0.3281, Test Accuracy: 0.2031, Loss: 2.9704
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 3.1475
# Train Accuracy: 0.3906, Test Accuracy: 0.2812, Loss: 3.0704
# Train Accuracy: 0.2344, Test Accuracy: 0.3125, Loss: 3.3059
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.8237
# Train Accuracy: 0.1875, Test Accuracy: 0.3281, Loss: 3.2014
# Train Accuracy: 0.2500, Test Accuracy: 0.2969, Loss: 3.0981
# Train Accuracy: 0.2500, Test Accuracy: 0.3594, Loss: 3.3066
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.3589
# Train Accuracy: 0.2500, Test Accuracy: 0.3125, Loss: 3.0355
# Train Accuracy: 0.4062, Test Accuracy: 0.2969, Loss: 2.8893
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.2866
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 3.3007
# Train Accuracy: 0.2812, Test Accuracy: 0.2656, Loss: 2.9753
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.4126
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.2940
# Train Accuracy: 0.2344, Test Accuracy: 0.2969, Loss: 2.9961
# Train Accuracy: 0.2656, Test Accuracy: 0.2344, Loss: 3.2259
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.2995
# Train Accuracy: 0.1250, Test Accuracy: 0.2969, Loss: 3.6534
# Train Accuracy: 0.2656, Test Accuracy: 0.2188, Loss: 3.3142
# Train Accuracy: 0.3125, Test Accuracy: 0.2656, Loss: 3.0491
# Train Accuracy: 0.2031, Test Accuracy: 0.2500, Loss: 2.8834
# Train Accuracy: 0.2031, Test Accuracy: 0.2188, Loss: 3.1788
# Train Accuracy: 0.2344, Test Accuracy: 0.2656, Loss: 3.3179
# Train Accuracy: 0.1250, Test Accuracy: 0.2500, Loss: 3.4088
# Train Accuracy: 0.3281, Test Accuracy: 0.2656, Loss: 2.7592
# Train Accuracy: 0.2812, Test Accuracy: 0.2188, Loss: 3.1578
# Train Accuracy: 0.2188, Test Accuracy: 0.3438, Loss: 3.4850
# Train Accuracy: 0.2031, Test Accuracy: 0.2812, Loss: 3.3363
# Train Accuracy: 0.1562, Test Accuracy: 0.2188, Loss: 3.4411
# Train Accuracy: 0.2344, Test Accuracy: 0.1719, Loss: 2.9019
# Train Accuracy: 0.2969, Test Accuracy: 0.2188, Loss: 2.8390
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 2.9709
# Train Accuracy: 0.1719, Test Accuracy: 0.2344, Loss: 3.1481
# Train Accuracy: 0.3750, Test Accuracy: 0.3594, Loss: 2.5936
# Train Accuracy: 0.3125, Test Accuracy: 0.1875, Loss: 2.9486
# Train Accuracy: 0.1719, Test Accuracy: 0.2812, Loss: 3.5109
# Train Accuracy: 0.1719, Test Accuracy: 0.3125, Loss: 2.8700
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.2153
# Train Accuracy: 0.3281, Test Accuracy: 0.2344, Loss: 2.8279
# Train Accuracy: 0.3281, Test Accuracy: 0.2031, Loss: 3.1165
# Train Accuracy: 0.2188, Test Accuracy: 0.2031, Loss: 3.2477
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 2.8508
# Train Accuracy: 0.3125, Test Accuracy: 0.2500, Loss: 3.3242
# Train Accuracy: 0.3281, Test Accuracy: 0.2500, Loss: 2.7127
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 3.2186
# Train Accuracy: 0.2812, Test Accuracy: 0.2500, Loss: 2.8250
# Train Accuracy: 0.4219, Test Accuracy: 0.2344, Loss: 2.8035
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.1454
# Train Accuracy: 0.3281, Test Accuracy: 0.2500, Loss: 3.0160
# Train Accuracy: 0.1875, Test Accuracy: 0.2344, Loss: 3.4947
# Train Accuracy: 0.3281, Test Accuracy: 0.2500, Loss: 2.9977
# Train Accuracy: 0.2031, Test Accuracy: 0.2656, Loss: 3.2588
# Train Accuracy: 0.3750, Test Accuracy: 0.1875, Loss: 2.9488
# Train Accuracy: 0.2969, Test Accuracy: 0.2969, Loss: 3.1842
# Train Accuracy: 0.2969, Test Accuracy: 0.3125, Loss: 3.1010
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.4676
# Train Accuracy: 0.3594, Test Accuracy: 0.2969, Loss: 3.1031
# Train Accuracy: 0.2656, Test Accuracy: 0.2500, Loss: 3.5406
# Train Accuracy: 0.3281, Test Accuracy: 0.2188, Loss: 2.8614
# Train Accuracy: 0.3906, Test Accuracy: 0.2812, Loss: 3.1493
# Train Accuracy: 0.2969, Test Accuracy: 0.2812, Loss: 2.7369
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.2198
# Train Accuracy: 0.3438, Test Accuracy: 0.2500, Loss: 2.9908
# Train Accuracy: 0.2656, Test Accuracy: 0.3281, Loss: 3.1604
# Train Accuracy: 0.2656, Test Accuracy: 0.3125, Loss: 2.9447
# Train Accuracy: 0.2188, Test Accuracy: 0.2812, Loss: 3.3829
# Train Accuracy: 0.2031, Test Accuracy: 0.3125, Loss: 3.3587
# Train Accuracy: 0.2031, Test Accuracy: 0.2188, Loss: 3.2327
# Train Accuracy: 0.3750, Test Accuracy: 0.2969, Loss: 3.1905
# Train Accuracy: 0.3438, Test Accuracy: 0.3125, Loss: 3.1975
# Train Accuracy: 0.1562, Test Accuracy: 0.2969, Loss: 3.6843
# Train Accuracy: 0.2812, Test Accuracy: 0.3281, Loss: 3.4155
# Train Accuracy: 0.2656, Test Accuracy: 0.2812, Loss: 3.2493
# Train Accuracy: 0.3438, Test Accuracy: 0.2812, Loss: 3.1690
# Train Accuracy: 0.2656, Test Accuracy: 0.2969, Loss: 3.5230
# Train Accuracy: 0.2969, Test Accuracy: 0.2344, Loss: 3.1204
# Train Accuracy: 0.1250, Test Accuracy: 0.2500, Loss: 3.8518
# Train Accuracy: 0.3281, Test Accuracy: 0.2969, Loss: 3.0511
# Train Accuracy: 0.2969, Test Accuracy: 0.2656, Loss: 3.1090
# Train Accuracy: 0.2188, Test Accuracy: 0.2500, Loss: 3.5828
# Train Accuracy: 0.2812, Test Accuracy: 0.2812, Loss: 3.1586
# Train Accuracy: 0.2969, Test Accuracy: 0.2500, Loss: 3.2776
# Train Accuracy: 0.3281, Test Accuracy: 0.3125, Loss: 2.9377
# Train Accuracy: 0.2656, Test Accuracy: 0.3438, Loss: 3.2177
# Train Accuracy: 0.3281, Test Accuracy: 0.2812, Loss: 2.7543
# Train Accuracy: 0.3594, Test Accuracy: 0.2188, Loss: 2.8793
# Train Accuracy: 0.2656, Test Accuracy: 0.2656, Loss: 3.2167
# Train Accuracy: 0.2500, Test Accuracy: 0.2656, Loss: 3.3110
# Train Accuracy: 0.2656, Test Accuracy: 0.2586, Loss: 3.2257
# Model saved to trained_esn_model.pth

# %%
cp -r /content/model /content/drive/MyDrive/kanboost3_24

# %% [markdown]
# # Prefetch File Generation

# %%
dataset=prepare_dataset(input_features=input_features,output_labels=output_labels,device=device)

# %%
dataset['input'][0:5]
# Out:
# tensor([[65., 65., 65., 65., 65.],
#         [65., 65., 65., 65., 65.],
#         [65., 65., 65., 65., 65.],
#         [65., 76., 66., 65., 65.],
#         [65., 65., 65., 15., 15.]], device='cuda:0')

# %%
output_dim=128
indivsize=1000
num_layers=6
reservoir_sizes=[]
for i in range(0,num_layers):
  reservoir_sizes.append(num_layers)
esn_model = DeepEchoStateNetwork(input_dim, reservoir_sizes, output_dim,spectral_radius=0.95)

# Load the saved state
esn_model.load_state_dict(torch.load("trained_esn_model.pth"))

# Move to appropriate device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
esn_model = esn_model.to(device)

# Set the model to evaluation mode
esn_model.eval()
# Out:
# <ipython-input-78-7b355e755d68>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   esn_model.load_state_dict(torch.load("trained_esn_model.pth"))
# DeepEchoStateNetwork(
#   (Wout): Linear(in_features=6, out_features=128, bias=True)
# )

# %%
# !ls
# Out:
# 0.7_cache_data.zip  0.7_state	   drive	kanboost  sample_data
# 0.7_config.yml	    0.7_state.zip  history.txt	model

# %%
# !cd "model"
# !ls
# Out:
# drive  model  sample_data

# %%
def generate_prefetch_file(path, prefetches):
    with open(path, 'w') as f:
        for instr_id, pf_addr in prefetches:
            print(instr_id, pf_addr, file=f)
def prefetch_generation(batch_size=5000):
    """
    Prepare dataset with manual batching.
    Returns the average inference time per sample in nanoseconds.
    """
    import time

    # Get the total number of samples
    total_samples = len(input_features)
    total_inference_time = 0
    num_batches = 0
    prefetches = []

    # Create batches manually by splitting the data
    for i in range(0, total_samples, batch_size):
        batch_inputs = dataset['input'][i:i + batch_size]
        num_batches += 1
        batch_size_actual = len(batch_inputs)  # Adjust for the last batch

        # Measure inference time
        start_time = time.time()
        pred = torch.argmax(esn_model(batch_inputs), dim=1)
        inference_time = time.time() - start_time

        # Accumulate total inference time
        total_inference_time += inference_time

        # Process predictions
        for j in range(len(pred)):
            instr_id, load_address, _, _, _, _, _ = input_features[i + j]
            load_addr = preprocessor.unsplit_load_address(load_address, int(pred[j].item()) - 64)
            prefetches.append((instr_id, load_addr))

    # Calculate average inference time per sample in nanoseconds
    avg_inference_time_per_sample_ns = (total_inference_time / total_samples) * 1e9 if total_samples > 0 else 0
    print(f"Average Inference Time per Sample: {avg_inference_time_per_sample_ns:.2f} nanoseconds")

    return avg_inference_time_per_sample_ns, prefetches

# %%
prefetches=[]
avgtime,prefetches=prefetch_generation()
generate_prefetch_file('prefetch_1M_model_v0.5.txt', prefetches)
# Out:
# Average Inference Time per Sample: 129.75 nanoseconds

# %%
len(prefetches),len(input_features)
# Out:
# (260492, 260492)
